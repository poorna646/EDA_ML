# %% [markdown]
# 1.DATA
#
# 2.DOMAIN KNOWLEDGE
#      ------POST PROCESSING-----
#
# 3.DATA CLEAN(missing data,duplicate,outliers)
#
# 4.EDA(charts, stats, graphs)
#
# 5.FEATURE ENGINEERING(normalization,standardization,dimentionity reduction(comes under unsupervised learning) - eigen value, eigen vectors)
#
# 6.FEATURE SELECTION (correlation, feature dependency, plot)
# =>separate the datas into train,test(80-20)
#
# 7.MODEL(define the model,choosed based on datatypes)
#
# 8.COMPILE THE MODEL(loss function(tells how to handle losses)- eg:least mean square, optimizers - doing adjustment / changes , Metrics - checking for accuracy-classificaton,FNscore,MSE-regression)
#
# 9.MODEL FIT - model + data , epochs
#       --------POST processing-----
#
# 10.EVALUATIION
# 11.HYPERPARAMETER TUNING(grid search - with maximum combinations - gives a paramter that gives high parameter)
#
# 12.WEIGHS EXPORT
#
#
# EXPLORATORY DATA ANALYSIS -
# * gain insights into data
# * identify patterns
# * identify anomalies
# * understand the relationaships within data
#
# TASKS:
# *data cleaning
# *data exploration
# *data visualization
#
# DATA PREPARATION
# * handles null values(null values can be replaced with mean,mode,median - constraint is that the given value should not give a big differnce)
# * all units should be in same scale
# * handles irrelavent datas
# * reduce redundancy
# * normalizing- keeping a numbers in particular range
# * identifying outliers - to idenify outliers drop the value

# %%
import pandas as pd
import numpy as np

# %%
path= "https://raw.githubusercontent.com/nunnarilabs/ml/master/Automobile_Data/automobile_data.csv"
data=pd.read_csv(path)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.replace("?",np.nan,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data.shape
# Out:
# (205, 26)

# %%
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# *unique* variant- x & y
# More than two featues-muti-varaint
# x1.x2 & y
# y(target)
# x(predicted value)

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# HANDLING MISSING DATA
# *isnull()
# *notnull()
#
# DEALING WITH MISSING VALUES:
# * drop data(row/ column)
# * replace data(with mean, freq)

# %%
#calculate mean
avg_norm_loss=data["normalized-losses"].astype("float").mean(axis=0) #axis=0-for row , but reflects on column when accessing , axis=1-column - axis given inside mean
avg_norm_loss
# Out:
# 122.0

# %%
#replace with mean
data["normalized-losses"].replace(np.nan,avg_norm_loss,inplace=True)

# %%
#mean of bore
avg_bore=data['bore'].astype('float').mean(axis=0)

# %%
data["bore"].replace(np.nan,avg_norm_loss,inplace=True)

# %%
data['num-of-doors'].mode() #returns series
# Out:
# 0    four
# Name: num-of-doors, dtype: object

# %%
data['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
data['num-of-doors'].replace(np.nan,'four',inplace=True)

# %%
data['stroke'].replace(np.nan,data['stroke'].astype('float').mean(axis=0),inplace=True)
data['horsepower'].replace(np.nan,data['horsepower'].astype('float').mean(axis=0),inplace=True)
data['peak-rpm'].replace(np.nan,data['peak-rpm'].astype('float').mean(axis=0),inplace=True)

# %% [markdown]
# DROP ROWS

# %%
data.dropna(subset=["price"],axis=0,inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#convert columns to right datatypes
data[["bore","stroke"]]=data[["bore","stroke"]].astype("float")
data[["normalized-losses"]]=data[["normalized-losses"]].astype("int")
data[["price"]]=data[["price"]].astype("float")
data[["peak-rpm"]]=data[["peak-rpm"]].astype("float")
data[["horsepower"]]=data[["horsepower"]].astype("float")

# %% [markdown]
# IDENTIFYING OUTLIERS
#
#
# *   Z-score(used for normalization)- also called standard score, tells how far the data point from mean[(x-x mean)/std deviation]
# *   IQR(Inter Quartile Range) - finds outliers

# %%
#outlier detection using z-score
from scipy import stats
hp_zscore=np.abs(stats.zscore(data['normalized-losses']))
hp_zscore
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      1.315931
# 4      1.315931
#          ...
# 196    0.845956
# 197    0.845956
# 198    0.845956
# 199    0.845956
# 200    0.845956
# Name: normalized-losses, Length: 201, dtype: float64

# %%
#set a threshold
threshold = hp_zscore.max()
threshold
# Out:
# 4.198447731100787

# %%
#position of the outlier
index_val=np.where(hp_zscore >= threshold)
data.iloc[index_val]['normalized-losses']
# Out:
# 186    256
# Name: normalized-losses, dtype: int64

# %%
#drop the row that has the outlier
new_data=data.drop(index=data.iloc[index_val]['normalized-losses'].index)
new_data
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            3                122  alfa-romero       gas        std
# 2            1                122  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
#calculate upper and lower limits

Q1= data['length'].quantile(0.25)
Q3 = data['length'].quantile(0.75)
IQR= Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 +1.5*IQR

#create arrays of boolean values indicating outlier rows
upper_array =np.where(data['length']>=upper)[0]
lower_array =np.where(data['length']<=lower)[0]

# %%
Q1
# Out:
# 166.8

# %% [markdown]
# DATA EXPLORATION- visualizing the data distribution and understanding relation b/w varaibles

# %%
data.describe(include=['object'])
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %% [markdown]
# VALUE_COUNTS

# %%
data['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts=data['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels':'value_counts'},inplace=True)
drive_wheels_counts.index.name='drive_wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive_wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %% [markdown]
# GROUPING - groups data by d/t categories , grouped based on one or severl varaibles and analysis is performed on individual groups

# %%
data['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one=data[['drive-wheels','price']]
df_group_one.head()
# Out:
#   drive-wheels    price
# 0          rwd  13495.0
# 1          rwd  16500.0
# 2          rwd  16500.0
# 3          fwd  13950.0
# 4          4wd  17450.0

# %%
df_gptest = data[['drive-wheels','body-style','price']]
grouped_test1= df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot =  grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot=grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# CORRELATION -  measure of extent of interdependence between varaibles
#             -  change in one change the independent one
# CAUSATION -  relation b/w cause and effect between 2 varaibles
#           -  change in one thing make change in dependent one
#
#  ranges from -1 to 1
#
# PEARSON CORRELATION- measures linear relation

# %%
data.corr()
# Out:
# <ipython-input-134-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore                0.243521           0.124511   -0.074380 -0.050463
# ...

# %%
import seaborn as sns

# %%
corre=data.corr()
# Out:
# <ipython-input-136-0b7006ea44c3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corre=data.corr()

# %%
sns.heatmap(corre,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# F TEST- gives varaiance between two varaibles

# %% [markdown]
# DATA STANDARDIZATION

# %%
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
#convert mpg to l/100km by mathemetical operation(235 divided by mpg)
data['city-L/100km'] = 235/data["city-mpg"]
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
#create a sample datset
data1=[[1,2],[3,4],[5,6]]
#initialize standardScaler
scaler= StandardScaler()
#fit the scaler on data and transform it
standardized_data = scaler.fit_transform(data1)
print("Original data : ")
print(data1)
print("\nstandardized data : ")
print(standardized_data)
# Out:
# Original data :
# [[1, 2], [3, 4], [5, 6]]
#
# standardized data :
# [[-1.22474487 -1.22474487]
#  [ 0.          0.        ]
#  [ 1.22474487  1.22474487]]

# %% [markdown]
# mean of 1sr column= (1+3+5)/3=3
#
# std dev of 1st column=var=(4+0+4)/3,std dev=sqrt(2.66)=1.63
#
# mean of 2nd column=(2+4+6)/3=4
#
# std dev of 2nd column=var=(4+0+4)/3,std dev=1.63

# %%
np.max(data1)-data1
# Out:
# array([[5, 4],
#        [3, 2],
#        [1, 0]])

# %%
data['length']=data['length']/data['length'].max()
data['width']=data['width']/data['width'].max()
data['height']=data['height']/data['height'].max()
data[['length','width','height']]
# Out:
#        length     width    height
# 0    0.811148  0.890278  0.816054
# 1    0.811148  0.890278  0.816054
# 2    0.822681  0.909722  0.876254
# 3    0.848630  0.919444  0.908027
# 4    0.848630  0.922222  0.908027
# ..        ...       ...       ...
# 196  0.907256  0.956944  0.928094
# 197  0.907256  0.955556  0.928094
# 198  0.907256  0.956944  0.928094
# 199  0.907256  0.956944  0.928094
# 200  0.907256  0.956944  0.928094
#
# [201 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler # MinMaxScaler=val-min/max-min
scaler= MinMaxScaler()
scaled_data = scaler.fit_transform(data1)
scaled_data
# Out:
# array([[0. , 0. ],
#        [0.5, 0.5],
#        [1. , 1. ]])
